# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df = pd.read_csv("C:\Info\KLAP\horse-betting\databases\courses.csv", index_col=0)
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (31,32,42,43,45,49,50,51,52,53,54,57,58,59,62,63,64,67,68,69,70,71,73,76,77,78,80,83,84,85,87,90,91,92,94,97,98,99,101,104,105,106,108,111,112,113,115,118,119,120,122,125,126,127,129,132,133,134,136,139,140) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   fieldQuality sexCategory raceCategory    raceType raceSecondType  \
# 0         GOOD           M        GALOP     CLASS_F   A_CONDITIONS
# 1         GOOD           F        GALOP     CLASS_F   A_CONDITIONS
# 2         GOOD           M        GALOP  GROUPE_III            NaN
# 3         GOOD         NaN        GALOP     CLASS_D       HANDICAP
# 4         GOOD         NaN        GALOP  GROUPE_III            NaN
#
#    price_total  distance fieldType ropeSide      fieldName  \
# 0      24000.0      1600      TURF    RIGHT  Moyenne piste
# 1      24000.0      1600      TURF    RIGHT  Moyenne piste
# 2      80000.0      1600      TURF    RIGHT  Moyenne piste
# 3      48000.0      2000      TURF    RIGHT   Grande piste
# 4      80000.0      2000      TURF    RIGHT   Grande piste
#
#                                     humanDescription startType  \
# 0  Pour poulains entiers et hongres de 2 ans, n'a...   UNKNOWN
# 1  Pour pouliches de 2 ans, n'ayant jamais couru....   UNKNOWN
# 2  Pour poulains entiers et hongres de 2 ans, n'a...   UNKNOWN
# 3  Pour chevaux entiers, hongres et juments de 4 ...   UNKNOWN
# 4  Pour poulains entiers, hongres et pouliches de...   UNKNOWN
#
#    raceScheduledStartEpochMs  raceNumber  reunionNumber hippodromeName  \
# 0              1284809700000           1              1      LONGCHAMP
# 1              1284811500000           2              1      LONGCHAMP
# 2              1284813300000           3              1      LONGCHAMP
# 3              1284815280000           4              1      LONGCHAMP
# 4              1284817500000           5              1      LONGCHAMP
#
#                   raceName pays  \
# 0         PRIX DE FONTENOY  FRA
# 1       PRIX DE LA CASCADE  FRA
# 2          PRIX DES CHENES  FRA
# 3         PRIX DE LA TABLE  FRA
# 4  PRIX DU PRINCE D'ORANGE  FRA
#
#                                  photoFinishes_0_url    genyId       raceId  \
# 0  https://media.genybet.fr/web/photo/arv/73/phot...  312873.0  geny:312873
# 1  https://media.genybet.fr/web/photo/arv/74/phot...  312874.0  geny:312874
# 2  https://media.genybet.fr/web/photo/arv/75/phot...  312875.0  geny:312875
# 3  https://media.genybet.fr/web/photo/arv/76/phot...  312876.0  geny:312876
# 4  https://media.genybet.fr/web/photo/arv/77/phot...  312877.0  geny:312877
#
#                                  name_race           epreuve  \
# 0         2010-09-18_R1C1_PRIX DE FONTENOY               NaN
# 1       2010-09-18_R1C2_PRIX DE LA CASCADE               NaN
# 2          2010-09-18_R1C3_PRIX DES CHENES               NaN
# 3         2010-09-18_R1C4_PRIX DE LA TABLE  Première épreuve
# 4  2010-09-18_R1C5_PRIX DU PRINCE D'ORANGE               NaN
#
#    categoryHandicap  handicapRef_0  handicapRef_1  photoFinishes_1_height  \
# 0               NaN            NaN            NaN                     NaN
# 1               NaN            NaN            NaN                     NaN
# 2               NaN            NaN            NaN                     NaN
# 3  HANDICAP_DIVIDED           17.5           17.5                   427.0
# 4               NaN            NaN            NaN                     NaN
#
#    photoFinishes_1_width photoFinishes_1_originalSize  \
# 0                    NaN                          NaN
# 1                    NaN                          NaN
# 2                    NaN                          NaN
# 3                  640.0                         True
# 4                    NaN                          NaN
#
#                                  photoFinishes_1_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://www.canalturf.com/arriveesphotos/arriv...
# 4                                                NaN
#
#                          photoFinishes_1_description raceArrival raceGeoRange  \
# 0                                                NaN         NaN          NaN
# 1                                                NaN         NaN          NaN
# 2                                                NaN         NaN          NaN
# 3  <strong>SAGA DREAM</strong> et <strong>JARNET ...         NaN          NaN
# 4                                                NaN         NaN          NaN
#
#   apprentis  recul_distance  recul_value european jockeyCategory  \
# 0       NaN             NaN          NaN      NaN            NaN
# 1       NaN             NaN          NaN      NaN            NaN
# 2       NaN             NaN          NaN      NaN            NaN
# 3       NaN             NaN          NaN      NaN            NaN
# 4       NaN             NaN          NaN      NaN            NaN
#
#   challengeName  photoFinishes_0_height  photoFinishes_0_width  \
# 0           NaN                     NaN                    NaN
# 1           NaN                     NaN                    NaN
# 2           NaN                     NaN                    NaN
# 3           NaN                     NaN                    NaN
# 4           NaN                     NaN                    NaN
#
#   photoFinishes_0_originalSize photoFinishes_0_description  penetrometer  \
# 0                          NaN                         NaN           NaN
# 1                          NaN                         NaN           NaN
# 2                          NaN                         NaN           NaN
# 3                          NaN                         NaN           NaN
# 4                          NaN                         NaN           NaN
#
#   maiden  duration  price_first  price_fifth ageCategory ecuries_0_ecurieId  \
# 0    NaN       NaN          NaN          NaN         NaN                NaN
# 1    NaN       NaN          NaN          NaN         NaN                NaN
# 2    NaN       NaN          NaN          NaN         NaN                NaN
# 3    NaN       NaN          NaN          NaN         NaN                NaN
# 4    NaN       NaN          NaN          NaN         NaN                NaN
#
#   breedCategory ecuries_1_ecurieId ecuries_2_ecurieId ecuries_3_ecurieId  \
# 0           NaN                NaN                NaN                NaN
# 1           NaN                NaN                NaN                NaN
# 2           NaN                NaN                NaN                NaN
# 3           NaN                NaN                NaN                NaN
# 4           NaN                NaN                NaN                NaN
#
#    photoFinishes_2_height  photoFinishes_2_width photoFinishes_2_url  \
# 0                     NaN                    NaN                 NaN
# 1                     NaN                    NaN                 NaN
# 2                     NaN                    NaN                 NaN
# 3                     NaN                    NaN                 NaN
# 4                     NaN                    NaN                 NaN
#
#   photoFinishes_2_originalSize photoFinishes_3_url  photoFinishes_4_height  \
# 0                          NaN                 NaN                     NaN
# 1                          NaN                 NaN                     NaN
# 2                          NaN                 NaN                     NaN
# 3                          NaN                 NaN                     NaN
# 4                          NaN                 NaN                     NaN
#
#    photoFinishes_4_width photoFinishes_4_originalSize photoFinishes_4_url  \
# 0                    NaN                          NaN                 NaN
# 1                    NaN                          NaN                 NaN
# 2                    NaN                          NaN                 NaN
# 3                    NaN                          NaN                 NaN
# 4                    NaN                          NaN                 NaN
#
#   photoFinishes_4_description  photoFinishes_3_height  photoFinishes_3_width  \
# 0                         NaN                     NaN                    NaN
# 1                         NaN                     NaN                    NaN
# 2                         NaN                     NaN                    NaN
# 3                         NaN                     NaN                    NaN
# 4                         NaN                     NaN                    NaN
#
#   photoFinishes_3_originalSize photoFinishes_3_description ecuries_4_ecurieId  \
# 0                          NaN                         NaN                NaN
# 1                          NaN                         NaN                NaN
# 2                          NaN                         NaN                NaN
# 3                          NaN                         NaN                NaN
# 4                          NaN                         NaN                NaN
#
#   feeOnly ecuries_0_odds_pmu_lastDirect_typeBet  \
# 0     NaN                                   NaN
# 1     NaN                                   NaN
# 2     NaN                                   NaN
# 3     NaN                                   NaN
# 4     NaN                                   NaN
#
#    ecuries_0_odds_pmu_lastDirect_ratio  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   ecuries_0_odds_pmu_lastDirect_typeRatio  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ecuries_0_odds_pmu_lastDirect_tendancyNumber  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ecuries_0_odds_pmu_lastDirect_epochMs  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   ecuries_0_odds_pmu_lastDirect_favorite  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   ecuries_0_odds_pmu_lastDirect_grossePrise  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_0_odds_pmu_lastReference_typeBet  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    ecuries_0_odds_pmu_lastReference_ratio  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   ecuries_0_odds_pmu_lastReference_typeRatio  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ecuries_0_odds_pmu_lastReference_tendancyNumber  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    ecuries_0_odds_pmu_lastReference_epochMs  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_0_odds_pmu_lastReference_favorite  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_0_odds_pmu_lastReference_grossePrise  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   ecuries_1_odds_pmu_lastDirect_typeBet  ecuries_1_odds_pmu_lastDirect_ratio  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#   ecuries_1_odds_pmu_lastDirect_typeRatio  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ecuries_1_odds_pmu_lastDirect_tendancyNumber  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ecuries_1_odds_pmu_lastDirect_epochMs  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   ecuries_1_odds_pmu_lastDirect_favorite  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   ecuries_1_odds_pmu_lastDirect_grossePrise  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_1_odds_pmu_lastReference_typeBet  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    ecuries_1_odds_pmu_lastReference_ratio  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   ecuries_1_odds_pmu_lastReference_typeRatio  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ecuries_1_odds_pmu_lastReference_tendancyNumber  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    ecuries_1_odds_pmu_lastReference_epochMs  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_1_odds_pmu_lastReference_favorite  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_1_odds_pmu_lastReference_grossePrise  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   ecuries_2_odds_pmu_lastDirect_typeBet  ecuries_2_odds_pmu_lastDirect_ratio  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#   ecuries_2_odds_pmu_lastDirect_typeRatio  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ecuries_2_odds_pmu_lastDirect_tendancyNumber  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ecuries_2_odds_pmu_lastDirect_epochMs  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   ecuries_2_odds_pmu_lastDirect_favorite  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   ecuries_2_odds_pmu_lastDirect_grossePrise  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_2_odds_pmu_lastReference_typeBet  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    ecuries_2_odds_pmu_lastReference_ratio  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   ecuries_2_odds_pmu_lastReference_typeRatio  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ecuries_2_odds_pmu_lastReference_tendancyNumber  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    ecuries_2_odds_pmu_lastReference_epochMs  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_2_odds_pmu_lastReference_favorite  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_2_odds_pmu_lastReference_grossePrise  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   ecuries_3_odds_pmu_lastDirect_typeBet  ecuries_3_odds_pmu_lastDirect_ratio  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#   ecuries_3_odds_pmu_lastDirect_typeRatio  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ecuries_3_odds_pmu_lastDirect_tendancyNumber  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ecuries_3_odds_pmu_lastDirect_epochMs  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   ecuries_3_odds_pmu_lastDirect_favorite  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   ecuries_3_odds_pmu_lastDirect_grossePrise  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_3_odds_pmu_lastReference_typeBet  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    ecuries_3_odds_pmu_lastReference_ratio  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   ecuries_3_odds_pmu_lastReference_typeRatio  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ecuries_3_odds_pmu_lastReference_tendancyNumber  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    ecuries_3_odds_pmu_lastReference_epochMs  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_3_odds_pmu_lastReference_favorite  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_3_odds_pmu_lastReference_grossePrise  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   ecuries_4_odds_pmu_lastDirect_typeBet  ecuries_4_odds_pmu_lastDirect_ratio  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#   ecuries_4_odds_pmu_lastDirect_typeRatio  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ecuries_4_odds_pmu_lastDirect_tendancyNumber  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ecuries_4_odds_pmu_lastDirect_epochMs  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   ecuries_4_odds_pmu_lastDirect_favorite  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   ecuries_4_odds_pmu_lastDirect_grossePrise  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_4_odds_pmu_lastReference_typeBet  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    ecuries_4_odds_pmu_lastReference_ratio  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   ecuries_4_odds_pmu_lastReference_typeRatio  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ecuries_4_odds_pmu_lastReference_tendancyNumber  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    ecuries_4_odds_pmu_lastReference_epochMs  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_4_odds_pmu_lastReference_favorite  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   ecuries_4_odds_pmu_lastReference_grossePrise
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN

# %%
df.dtypes
# Out:
# fieldQuality                                        object
# sexCategory                                         object
# raceCategory                                        object
# raceType                                            object
# raceSecondType                                      object
# price_total                                        float64
# distance                                             int64
# fieldType                                           object
# ropeSide                                            object
# fieldName                                           object
# humanDescription                                    object
# startType                                           object
# raceScheduledStartEpochMs                            int64
# raceNumber                                           int64
# reunionNumber                                        int64
# hippodromeName                                      object
# raceName                                            object
# pays                                                object
# photoFinishes_0_url                                 object
# genyId                                             float64
# raceId                                              object
# name_race                                           object
# epreuve                                             object
# categoryHandicap                                    object
# handicapRef_0                                      float64
# handicapRef_1                                      float64
# photoFinishes_1_height                             float64
# photoFinishes_1_width                              float64
# photoFinishes_1_originalSize                        object
# photoFinishes_1_url                                 object
# photoFinishes_1_description                         object
# raceArrival                                         object
# raceGeoRange                                        object
# apprentis                                           object
# recul_distance                                     float64
# recul_value                                        float64
# european                                            object
# jockeyCategory                                      object
# challengeName                                       object
# photoFinishes_0_height                             float64
# photoFinishes_0_width                              float64
# photoFinishes_0_originalSize                        object
# photoFinishes_0_description                         object
# penetrometer                                       float64
# maiden                                              object
# duration                                           float64
# price_first                                        float64
# price_fifth                                        float64
# ageCategory                                         object
# ecuries_0_ecurieId                                  object
# breedCategory                                       object
# ecuries_1_ecurieId                                  object
# ecuries_2_ecurieId                                  object
# ecuries_3_ecurieId                                  object
# photoFinishes_2_height                             float64
# photoFinishes_2_width                              float64
# photoFinishes_2_url                                 object
# photoFinishes_2_originalSize                        object
# photoFinishes_3_url                                 object
# photoFinishes_4_height                             float64
# photoFinishes_4_width                              float64
# photoFinishes_4_originalSize                        object
# photoFinishes_4_url                                 object
# photoFinishes_4_description                         object
# photoFinishes_3_height                             float64
# photoFinishes_3_width                              float64
# photoFinishes_3_originalSize                        object
# photoFinishes_3_description                         object
# ecuries_4_ecurieId                                  object
# feeOnly                                             object
# ecuries_0_odds_pmu_lastDirect_typeBet               object
# ecuries_0_odds_pmu_lastDirect_ratio                float64
# ecuries_0_odds_pmu_lastDirect_typeRatio             object
# ecuries_0_odds_pmu_lastDirect_tendancyNumber       float64
# ecuries_0_odds_pmu_lastDirect_epochMs              float64
# ecuries_0_odds_pmu_lastDirect_favorite              object
# ecuries_0_odds_pmu_lastDirect_grossePrise           object
# ecuries_0_odds_pmu_lastReference_typeBet            object
# ecuries_0_odds_pmu_lastReference_ratio             float64
# ecuries_0_odds_pmu_lastReference_typeRatio          object
# ecuries_0_odds_pmu_lastReference_tendancyNumber    float64
# ecuries_0_odds_pmu_lastReference_epochMs           float64
# ecuries_0_odds_pmu_lastReference_favorite           object
# ecuries_0_odds_pmu_lastReference_grossePrise        object
# ecuries_1_odds_pmu_lastDirect_typeBet               object
# ecuries_1_odds_pmu_lastDirect_ratio                float64
# ecuries_1_odds_pmu_lastDirect_typeRatio             object
# ecuries_1_odds_pmu_lastDirect_tendancyNumber       float64
# ecuries_1_odds_pmu_lastDirect_epochMs              float64
# ecuries_1_odds_pmu_lastDirect_favorite              object
# ecuries_1_odds_pmu_lastDirect_grossePrise           object
# ecuries_1_odds_pmu_lastReference_typeBet            object
# ecuries_1_odds_pmu_lastReference_ratio             float64
# ecuries_1_odds_pmu_lastReference_typeRatio          object
# ecuries_1_odds_pmu_lastReference_tendancyNumber    float64
# ecuries_1_odds_pmu_lastReference_epochMs           float64
# ecuries_1_odds_pmu_lastReference_favorite           object
# ecuries_1_odds_pmu_lastReference_grossePrise        object
# ecuries_2_odds_pmu_lastDirect_typeBet               object
# ecuries_2_odds_pmu_lastDirect_ratio                float64
# ecuries_2_odds_pmu_lastDirect_typeRatio             object
# ecuries_2_odds_pmu_lastDirect_tendancyNumber       float64
# ecuries_2_odds_pmu_lastDirect_epochMs              float64
# ecuries_2_odds_pmu_lastDirect_favorite              object
# ecuries_2_odds_pmu_lastDirect_grossePrise           object
# ecuries_2_odds_pmu_lastReference_typeBet            object
# ecuries_2_odds_pmu_lastReference_ratio             float64
# ecuries_2_odds_pmu_lastReference_typeRatio          object
# ecuries_2_odds_pmu_lastReference_tendancyNumber    float64
# ecuries_2_odds_pmu_lastReference_epochMs           float64
# ecuries_2_odds_pmu_lastReference_favorite           object
# ecuries_2_odds_pmu_lastReference_grossePrise        object
# ecuries_3_odds_pmu_lastDirect_typeBet               object
# ecuries_3_odds_pmu_lastDirect_ratio                float64
# ecuries_3_odds_pmu_lastDirect_typeRatio             object
# ecuries_3_odds_pmu_lastDirect_tendancyNumber       float64
# ecuries_3_odds_pmu_lastDirect_epochMs              float64
# ecuries_3_odds_pmu_lastDirect_favorite              object
# ecuries_3_odds_pmu_lastDirect_grossePrise           object
# ecuries_3_odds_pmu_lastReference_typeBet            object
# ecuries_3_odds_pmu_lastReference_ratio             float64
# ecuries_3_odds_pmu_lastReference_typeRatio          object
# ecuries_3_odds_pmu_lastReference_tendancyNumber    float64
# ecuries_3_odds_pmu_lastReference_epochMs           float64
# ecuries_3_odds_pmu_lastReference_favorite           object
# ecuries_3_odds_pmu_lastReference_grossePrise        object
# ecuries_4_odds_pmu_lastDirect_typeBet               object
# ecuries_4_odds_pmu_lastDirect_ratio                float64
# ecuries_4_odds_pmu_lastDirect_typeRatio             object
# ecuries_4_odds_pmu_lastDirect_tendancyNumber       float64
# ecuries_4_odds_pmu_lastDirect_epochMs              float64
# ecuries_4_odds_pmu_lastDirect_favorite              object
# ecuries_4_odds_pmu_lastDirect_grossePrise           object
# ecuries_4_odds_pmu_lastReference_typeBet            object
# ecuries_4_odds_pmu_lastReference_ratio             float64
# ecuries_4_odds_pmu_lastReference_typeRatio          object
# ecuries_4_odds_pmu_lastReference_tendancyNumber    float64
# ecuries_4_odds_pmu_lastReference_epochMs           float64
# ecuries_4_odds_pmu_lastReference_favorite           object
# ecuries_4_odds_pmu_lastReference_grossePrise        object
# dtype: object

# %%
mask = (df.count() >= 20000)
print(f'Sélection de {np.sum(mask)} colonnes')
filter = [column for i, column in enumerate(df.columns.to_list()) if mask[i] and not("photo" in column)]
df = df[filter]
df.info()
# Out:
# Sélection de 48 colonnes
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138950 entries, 0 to 138949
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   fieldQuality               138950 non-null  object
#  1   sexCategory                116977 non-null  object
#  2   raceCategory               138950 non-null  object
#  3   raceType                   136611 non-null  object
#  4   raceSecondType             61233 non-null   object
#  5   price_total                138943 non-null  float64
#  6   distance                   138950 non-null  int64
#  7   fieldType                  138950 non-null  object
#  8   ropeSide                   137837 non-null  object
#  9   fieldName                  29819 non-null   object
#  10  humanDescription           138791 non-null  object
#  11  startType                  138950 non-null  object
#  12  raceScheduledStartEpochMs  138950 non-null  int64
#  13  raceNumber                 138950 non-null  int64
#  14  reunionNumber              138950 non-null  int64
#  15  hippodromeName             138950 non-null  object
#  16  raceName                   138950 non-null  object
#  17  pays                       138950 non-null  object
#  18  genyId                     138535 non-null  float64
#  19  raceId                     138950 non-null  object
#  20  name_race                  138950 non-null  object
#  21  categoryHandicap           21083 non-null   object
#  22  recul_distance             24287 non-null   float64
#  23  recul_value                23225 non-null   float64
#  24  penetrometer               38772 non-null   float64
#  25  duration                   106031 non-null  float64
#  26  price_first                107687 non-null  float64
#  27  price_fifth                107687 non-null  float64
#  28  ageCategory                55425 non-null   object
#  29  ecuries_0_ecurieId         24883 non-null   object
# dtypes: float64(8), int64(4), object(18)
# memory usage: 32.9+ MB

# %%
df.head()
# Out:
#   fieldQuality sexCategory raceCategory    raceType raceSecondType  \
# 0         GOOD           M        GALOP     CLASS_F   A_CONDITIONS
# 1         GOOD           F        GALOP     CLASS_F   A_CONDITIONS
# 2         GOOD           M        GALOP  GROUPE_III            NaN
# 3         GOOD         NaN        GALOP     CLASS_D       HANDICAP
# 4         GOOD         NaN        GALOP  GROUPE_III            NaN
#
#    price_total  distance fieldType ropeSide      fieldName  \
# 0      24000.0      1600      TURF    RIGHT  Moyenne piste
# 1      24000.0      1600      TURF    RIGHT  Moyenne piste
# 2      80000.0      1600      TURF    RIGHT  Moyenne piste
# 3      48000.0      2000      TURF    RIGHT   Grande piste
# 4      80000.0      2000      TURF    RIGHT   Grande piste
#
#                                     humanDescription startType  \
# 0  Pour poulains entiers et hongres de 2 ans, n'a...   UNKNOWN
# 1  Pour pouliches de 2 ans, n'ayant jamais couru....   UNKNOWN
# 2  Pour poulains entiers et hongres de 2 ans, n'a...   UNKNOWN
# 3  Pour chevaux entiers, hongres et juments de 4 ...   UNKNOWN
# 4  Pour poulains entiers, hongres et pouliches de...   UNKNOWN
#
#    raceScheduledStartEpochMs  raceNumber  reunionNumber hippodromeName  \
# 0              1284809700000           1              1      LONGCHAMP
# 1              1284811500000           2              1      LONGCHAMP
# 2              1284813300000           3              1      LONGCHAMP
# 3              1284815280000           4              1      LONGCHAMP
# 4              1284817500000           5              1      LONGCHAMP
#
#                   raceName pays    genyId       raceId  \
# 0         PRIX DE FONTENOY  FRA  312873.0  geny:312873
# 1       PRIX DE LA CASCADE  FRA  312874.0  geny:312874
# 2          PRIX DES CHENES  FRA  312875.0  geny:312875
# 3         PRIX DE LA TABLE  FRA  312876.0  geny:312876
# 4  PRIX DU PRINCE D'ORANGE  FRA  312877.0  geny:312877
#
#                                  name_race  categoryHandicap  recul_distance  \
# 0         2010-09-18_R1C1_PRIX DE FONTENOY               NaN             NaN
# 1       2010-09-18_R1C2_PRIX DE LA CASCADE               NaN             NaN
# 2          2010-09-18_R1C3_PRIX DES CHENES               NaN             NaN
# 3         2010-09-18_R1C4_PRIX DE LA TABLE  HANDICAP_DIVIDED             NaN
# 4  2010-09-18_R1C5_PRIX DU PRINCE D'ORANGE               NaN             NaN
#
#    recul_value  penetrometer  duration  price_first  price_fifth ageCategory  \
# 0          NaN           NaN       NaN          NaN          NaN         NaN
# 1          NaN           NaN       NaN          NaN          NaN         NaN
# 2          NaN           NaN       NaN          NaN          NaN         NaN
# 3          NaN           NaN       NaN          NaN          NaN         NaN
# 4          NaN           NaN       NaN          NaN          NaN         NaN
#
#   ecuries_0_ecurieId
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
df.describe()
# Out:
#         price_total       distance  raceScheduledStartEpochMs     raceNumber  \
# count  1.389430e+05  138950.000000               1.389500e+05  138950.000000
# mean   3.378474e+04    2413.007837               1.441640e+12       4.495775
# std    1.359588e+05     717.476098               8.071482e+10       2.358442
# min    1.000000e+00     800.000000               1.284804e+12       1.000000
# 25%    1.300000e+04    2000.000000               1.376570e+12       2.000000
# 50%    2.000000e+04    2400.000000               1.445089e+12       4.000000
# 75%    2.900000e+04    2850.000000               1.510488e+12       6.000000
# max    1.386022e+07    7300.000000               1.577819e+12      12.000000
#
#        reunionNumber        genyId  recul_distance    recul_value  \
# count  138950.000000  1.385350e+05    24287.000000   23225.000000
# mean        3.704577  7.374903e+05       22.760324   60592.354360
# std         2.530531  2.295566e+05       10.360181   72436.897462
# min         1.000000  2.723260e+05      -50.000000      36.000000
# 25%         2.000000  5.408065e+05       25.000000   21500.000000
# 50%         3.000000  7.578300e+05       25.000000   42000.000000
# 75%         5.000000  9.408425e+05       25.000000   73000.000000
# max        18.000000  1.119290e+06       50.000000  945000.000000
#
#        penetrometer      duration   price_first    price_fifth
# count  38772.000000  1.060310e+05  1.076870e+05  107687.000000
# mean       3.210675  1.742366e+05  1.167680e+04    1161.507248
# std        2.088520  6.330885e+04  3.502693e+04    2138.147832
# min        0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%        3.000000  1.263300e+05  5.400000e+03     550.000000
# 50%        3.400000  1.780100e+05  8.640000e+03     900.000000
# 75%        3.800000  2.154200e+05  1.250000e+04    1250.000000
# max      240.000000  1.812750e+06  4.547520e+06  227376.000000

# %%
sn.set(style="ticks")
fig, axs = plt.subplots(1, 2)
sn.barplot(data=df, x="raceType", y="price_total", ax=axs[0])
plt.xticks(rotation=90)
sn.scatterplot(data=df, x="distance", y="price_total", ax=axs[1])
plt.xticks(rotation=90)
plt.close(2)
plt.close(3)
